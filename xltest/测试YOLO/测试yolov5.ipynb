# %% [markdown]
# [参考链接](https://zhuanlan.zhihu.com/p/13491328897)

# %%
# !export https_proxy="http://127.0.0.1:10809"

# %%
import torch
from d2l import torch as d2l

# %%
torch.hub.list("ultralytics/yolov5:v7.0", force_reload=False, trust_repo=True)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_v7.0
# ['custom',
#  'yolov5l',
#  'yolov5l6',
#  'yolov5m',
#  'yolov5m6',
#  'yolov5n',
#  'yolov5n6',
#  'yolov5s',
#  'yolov5s6',
#  'yolov5x',
#  'yolov5x6']

# %%
model = torch.hub.load("ultralytics/yolov5:v7.0", "yolov5s", force_reload=False, trust_repo=True, device=d2l.try_gpu())
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_v7.0
# YOLOv5 🚀 2025-4-10 Python-3.9.21 torch-1.13.1 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11264MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
